# %% [markdown]
# # **CLIMATE CHANGE (EDA)**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('world_data_2023.csv')

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.head()
# Out:
#          Date Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001-01-15   India    West Bengal       Corn                   1.55
# 1  2024-01-15   China          North       Corn                   3.23
# 2  2001-01-15  France  Ile-de-France      Wheat                  21.11
# 3  2001-01-15  Canada       Prairies     Coffee                  27.85
# 4  1998-01-15   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# 1                       8                11.05                    33.06
# 2                       5                84.42                    27.41
# 3                       5                94.06                    14.38
# 4                       9                95.75                    44.35
#
#    Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 0                     14.78              83.25      Water Management
# 1                     23.25              54.02         Crop Rotation
# 2                     65.53              67.78      Water Management
# 3                     87.58              91.39         No Adaptation
# 4                     88.08              49.61         Crop Rotation
#
#    Economic_Impact_Million_USD
# 0                       808.13
# 1                       616.22
# 2                       796.96
# 3                       790.32
# 4                       401.72

# %%
df.sample(4)
# Out:
#             Date Country     Region Crop_Type  Average_Temperature_C  \
# 3622  2009-01-15     USA    Midwest  Soybeans                  11.86
# 4072  1998-01-15   China    Central    Barley                  19.77
# 1043  2001-01-15     USA    Midwest    Fruits                  32.51
# 2568  2000-01-15  Brazil  Southeast    Fruits                   0.19
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 3622                  751.90             11.49                 3.480
# 4072                 1503.54              8.01                 2.340
# 1043                 2320.84             16.24                 2.061
# 2568                 1133.58             24.03                 2.691
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 3622                       4                89.87                     2.85
# 4072                       0                40.81                    20.64
# 1043                       4                52.26                    19.20
# 2568                       1                25.96                    41.52
#
#       Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 3622                     14.82              74.13  Drought-resistant Crops
# 4072                     84.49              55.32            No Adaptation
# 1043                     28.94              39.36  Drought-resistant Crops
# 2568                     47.14              41.24            No Adaptation
#
#       Economic_Impact_Million_USD
# 3622                       810.55
# 4072                       764.28
# 1043                       891.82
# 2568                       468.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         10000 non-null  object
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
#  12  Soil_Health_Index            9991 non-null   float64
#  13  Adaptation_Strategies        9988 non-null   object
#  14  Economic_Impact_Million_USD  10000 non-null  float64
# dtypes: float64(9), int64(1), object(5)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        Average_Temperature_C  Total_Precipitation_mm  CO2_Emissions_MT  \
# count           10000.000000            10000.000000      10000.000000
# mean               15.241299             1611.663834         15.246608
# std                11.466955              805.016815          8.589423
# min                -4.990000              200.150000          0.500000
# 25%                 5.430000              925.697500          7.760000
# 50%                15.175000             1611.160000         15.200000
# 75%                25.340000             2306.997500         22.820000
# max                35.000000             2999.670000         30.000000
#
#        Crop_Yield_MT_per_HA  Extreme_Weather_Events  Irrigation_Access_%  \
# count          10000.000000            10000.000000         10000.000000
# mean               2.240017                4.980900            55.248332
# std                0.998342                3.165808            25.988305
# min                0.450000                0.000000            10.010000
# 25%                1.449000                2.000000            32.677500
# 50%                2.170000                5.000000            55.175000
# 75%                2.930000                8.000000            77.582500
# max                5.000000               10.000000            99.990000
#
#        Pesticide_Use_KG_per_HA  Fertilizer_Use_KG_per_HA  Soil_Health_Index  \
# count             10000.000000              10000.000000        9991.000000
# mean                 24.955735                 49.973708          64.895228
# std                  14.490962                 28.711027          20.197590
# min                   0.000000                  0.010000          30.000000
# 25%                  12.527500                 25.390000          47.215000
# 50%                  24.930000                 49.635000          64.650000
# 75%                  37.470000                 74.825000          82.465000
# max                  49.990000                 99.990000         100.000000
#
#        Economic_Impact_Million_USD
# count                 10000.000000
# mean                    674.269658
# std                     414.591431
# min                      47.840000
# 25%                     350.545000
# 50%                     583.920000
# 75%                     917.505000
# max                    2346.470000

# %%
df.columns
# Out:
# Index(['Date', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_%',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### 0) Handling Inconsistent Data

# %%
df.rename(columns={'Irrigation_Access_%': 'Irrigation_Access_Perc'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_Perc',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
categorical_cols = ['Country', 'Region', 'Crop_Type', 'Adaptation_Strategies']

for i in categorical_cols:
    print(f"Unique values in {i}:")
    print(df[i].value_counts())
    print("\n")
# Out:
# Unique values in Country:
# Country
# USA          1032
# Australia    1032
# China        1031
# Nigeria      1029
# India        1025
# Canada        984
# Argentina     984
# France        978
# Russia        961
# Brazil        944
# Name: count, dtype: int64
#
#
# Unique values in Region:
# Region
# South                         754
# Northeast                     752
# North                         524
# Central                       466
# Punjab                        288
# Victoria                      283
# New South Wales               276
# East                          273
# South West                    270
# Ontario                       269
# West Bengal                   267
# North West                    264
# Volga                         261
# South East                    260
# West                          257
# Grand Est                     254
# Queensland                    253
# Midwest                       253
# Nouvelle-Aquitaine            252
# Patagonia                     249
# Tamil Nadu                    249
# Northwest                     247
# Siberian                      246
# Prairies                      243
# British Columbia              242
# Provence-Alpes-Cote d’Azur    236
# Ile-de-France                 236
# North Central                 235
# Quebec                        230
# Northwestern                  227
# Pampas                        224
# Maharashtra                   221
# Western Australia             220
# Southeast                     219
# Name: count, dtype: int64
#
#
# Unique values in Crop_Type:
# Crop_Type
# Wheat         1047
# Cotton        1044
# Vegetables    1036
# Corn          1022
# Rice          1022
# Sugarcane      995
# Fruits         979
# Soybeans       958
# Barley         952
# Coffee         945
# Name: count, dtype: int64
#
#
# Unique values in Adaptation_Strategies:
# Adaptation_Strategies
# Water Management           2046
# No Adaptation              2020
# Drought-resistant Crops    1994
# Organic Farming            1974
# Crop Rotation              1954
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         10000 non-null  object
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_Perc       10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
#  12  Soil_Health_Index            9991 non-null   float64
#  13  Adaptation_Strategies        9988 non-null   object
#  14  Economic_Impact_Million_USD  10000 non-null  float64
# dtypes: float64(9), int64(1), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Converting the date column into date_time_stamp

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         10000 non-null  datetime64[ns]
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_Perc       10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
#  12  Soil_Health_Index            9991 non-null   float64
#  13  Adaptation_Strategies        9988 non-null   object
#  14  Economic_Impact_Million_USD  10000 non-null  float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 1)Handling Missing Data

# %%
df.isnull().sum()
# Out:
# Date                            0
# Country                         0
# Region                          0
# Crop_Type                       0
# Average_Temperature_C           0
# Total_Precipitation_mm          0
# CO2_Emissions_MT                0
# Crop_Yield_MT_per_HA            0
# Extreme_Weather_Events          0
# Irrigation_Access_Perc          0
# Pesticide_Use_KG_per_HA         0
# Fertilizer_Use_KG_per_HA        0
# Soil_Health_Index               9
# Adaptation_Strategies          12
# Economic_Impact_Million_USD     0
# dtype: int64

# %% [markdown]
# #### **Found Null values in two columns namely : Soil_health_index and Adaptation_strategies**

# %% [markdown]
# #### Filling(Imputing) Null Values in Soil_health_index Column

# %%
df.columns
# Out:
# Index(['Date', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_Perc',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = df[numeric_cols].corr()
soil_health_correlation = correlation_matrix['Soil_Health_Index'].sort_values(ascending=False)
soil_health_correlation
# Out:
# Soil_Health_Index              1.000000
# Extreme_Weather_Events         0.016619
# Pesticide_Use_KG_per_HA        0.012661
# CO2_Emissions_MT               0.004491
# Irrigation_Access_Perc         0.001660
# Fertilizer_Use_KG_per_HA      -0.000078
# Economic_Impact_Million_USD   -0.000690
# Crop_Yield_MT_per_HA          -0.006147
# Average_Temperature_C         -0.010874
# Total_Precipitation_mm        -0.021343
# Name: Soil_Health_Index, dtype: float64

# %% [markdown]
# Since there is no significant relationship between Soil_Health_Index and the categorical variables, it’s best to use a simple method like the mean, median imputation for filling missing values in Soil_Health_Index.

# %%
df['Soil_Health_Index'].plot(kind='hist',bins=109)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(df['Soil_Health_Index'], color='yellow', orient='h')
plt.title('Soil Health Index')
plt.show()

# %%
df['Soil_Health_Index'].describe()
# Out:
# count    9991.000000
# mean       64.895228
# std        20.197590
# min        30.000000
# 25%        47.215000
# 50%        64.650000
# 75%        82.465000
# max       100.000000
# Name: Soil_Health_Index, dtype: float64

# %%
df['Soil_Health_Index'].fillna(df['Soil_Health_Index'].mean(), inplace=True)

# %%
df['Soil_Health_Index'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Filling Null Values in Adaptation_Strategies Column

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

numerical_columns = ['Average_Temperature_C', 'Total_Precipitation_mm', 'CO2_Emissions_MT',
                     'Crop_Yield_MT_per_HA', 'Extreme_Weather_Events', 'Irrigation_Access_Perc',
                     'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA', 'Soil_Health_Index',
                     'Economic_Impact_Million_USD']

for col in numerical_columns:
    model = ols(f'{col} ~ C(Adaptation_Strategies)', data=df).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    print(f"ANOVA results for {col}:")
    print(anova_table)
    print("\n")
# Out:
# ANOVA results for Average_Temperature_C:
#                                 sum_sq      df         F    PR(>F)
# C(Adaptation_Strategies)  6.905708e+02     4.0  1.312922  0.262515
# Residual                  1.312715e+06  9983.0       NaN       NaN
#
#
# ANOVA results for Total_Precipitation_mm:
#                                 sum_sq      df         F    PR(>F)
# C(Adaptation_Strategies)  1.060311e+06     4.0  0.408806  0.802442
# Residual                  6.473169e+09  9983.0       NaN       NaN
#
#
# ANOVA results for CO2_Emissions_MT:
#                                  sum_sq      df         F    PR(>F)
# C(Adaptation_Strategies)     254.812008     4.0  0.863165  0.485152
# Residual                  736762.073474  9983.0       NaN       NaN
#
#
# ANOVA results for Crop_Yield_MT_per_HA:
#                                sum_sq      df        F    PR(>F)
# C(Adaptation_Strategies)     3.999118     4.0  1.00366  0.404083
# Residual                  9944.399823  9983.0      NaN       NaN
#
#
# ANOVA results for Extreme_Weather_Events:
#                                  sum_sq      df         F    PR(>F)
# C(Adaptation_Strategies)      35.051497     4.0  0.874443  0.478257
# Residual                  100040.595579  9983.0       NaN       NaN
#
#
# ANOVA results for Irrigation_Access_Perc:
#                                 sum_sq      df         F    PR(>F)
# C(Adaptation_Strategies)  1.318486e+03     4.0  0.488053  0.744547
# Residual                  6.742318e+06  9983.0       NaN       NaN
#
#
# ANOVA results for Pesticide_Use_KG_per_HA:
#                                 sum_sq      df         F    PR(>F)
# C(Adaptation_Strategies)  1.335241e+03     4.0  1.589157  0.174143
# Residual                  2.096978e+06  9983.0       NaN       NaN
#
#
# ANOVA results for Fertilizer_Use_KG_per_HA:
#                                 sum_sq      df         F  PR(>F)
# C(Adaptation_Strategies)  8.135588e+02     4.0  0.246673  0.9118
# Residual                  8.231296e+06  9983.0       NaN     NaN
#
#
# ANOVA results for Soil_Health_Index:
#                                 sum_sq      df         F  PR(>F)
# C(Adaptation_Strategies)  4.604086e+02     4.0  0.282151  0.8897
# Residual                  4.072520e+06  9983.0       NaN     NaN
#
#
# ANOVA results for Economic_Impact_Million_USD:
#                                 sum_sq      df         F    PR(>F)
# C(Adaptation_Strategies)  1.244339e+06     4.0  1.811271  0.123582
# Residual                  1.714574e+09  9983.0       NaN       NaN

# %%
from scipy.stats import chi2_contingency

categorical_columns = ['Country', 'Region', 'Crop_Type']

# Loop through each categorical column and perform Chi-Square test
for col in categorical_columns:
    contingency_table = pd.crosstab(df[col], df['Adaptation_Strategies'])
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    print(f"Chi-Square test results for {col}:")
    print(f"Chi2: {chi2}, p-value: {p}")
    print("\n")
# Out:
# Chi-Square test results for Country:
# Chi2: 30.944738542424215, p-value: 0.7076607106193358
#
#
# Chi-Square test results for Region:
# Chi2: 132.18449803127473, p-value: 0.47910882376663894
#
#
# Chi-Square test results for Crop_Type:
# Chi2: 45.23126866678453, p-value: 0.1392097117870732

# %%
df['Adaptation_Strategies'].value_counts()
# Out:
# Adaptation_Strategies
# Water Management           2058
# No Adaptation              2020
# Drought-resistant Crops    1994
# Organic Farming            1974
# Crop Rotation              1954
# Name: count, dtype: int64

# %%
df['Adaptation_Strategies'].mode()[0]
# Out:
# 'Water Management'

# %%
df['Adaptation_Strategies'].fillna(df['Adaptation_Strategies'].mode()[0], inplace=True)

# %%
df['Adaptation_Strategies'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 2) Handling Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3) Handling Outliers

# %%
# Select numerical columns
numerical_cols = ['Average_Temperature_C', 'Total_Precipitation_mm', 'CO2_Emissions_MT',
                  'Crop_Yield_MT_per_HA', 'Extreme_Weather_Events', 'Irrigation_Access_Perc',
                  'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA', 'Soil_Health_Index',
                  'Economic_Impact_Million_USD']

# Set the plot size
plt.figure(figsize=(16, 12))

# Create a boxplot for each numerical column
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 10),dpi=200)
sns.boxplot(df['Economic_Impact_Million_USD'], color='purple', orient='h')
plt.title('Economic_Impact_Million_USD')
plt.show()

# %%
plt.figure(figsize=(16, 8),dpi=200)
df['Economic_Impact_Million_USD'].plot(kind='hist',bins=50, color='black', alpha=0.7)
plt.title('Economic_Impact_Million_USD')
plt.show()

# %%
df['Economic_Impact_Million_USD'].describe()
# Out:
# count    10000.000000
# mean       674.269658
# std        414.591431
# min         47.840000
# 25%        350.545000
# 50%        583.920000
# 75%        917.505000
# max       2346.470000
# Name: Economic_Impact_Million_USD, dtype: float64

# %% [markdown]
# fill the outliers using IQR method

# %%
q1 = df['Economic_Impact_Million_USD'].quantile(0.25)
q3 = df['Economic_Impact_Million_USD'].quantile(0.75)
iqr = q3 - q1

# %%
print(f'Q1 : {q1}')
print(f'Q3 : {q3}')
print(f'IQR: {iqr}')
# Out:
# Q1 : 350.545
# Q3 : 917.505
# IQR: 566.96

# %%
lower_bound = q1 - 2 * iqr
upper_bound = q3 + 2 * iqr

# %%
print(f'Lower Bound : {lower_bound}')
print(f'Upper Bound : {upper_bound}')
# Out:
# Lower Bound : -783.375
# Upper Bound : 2051.425

# %% [markdown]
# 1. We will be losing more date when we use 1.5
# (lower_bound = q1 - 2 * iqr,
# upper_bound = q3 + 2 * iqr)
# . So i used 2
#
#
# 2. Neglecting the Lower bound because the minimun values of the column is far greater then the lower bound value.

# %% [markdown]
# Removing outliers greater than the Upper bound

# %%
df = df[df['Economic_Impact_Million_USD'] <= upper_bound]

# %%
plt.figure(figsize=(16, 8),dpi=200)
df['Economic_Impact_Million_USD'].plot(kind='hist',bins=50, color='Black', alpha=0.7)
plt.title('Economic_Impact_Million_USD')
plt.show()

# %%
df['Economic_Impact_Million_USD'].describe()
# Out:
# count    9958.000000
# mean      668.016206
# std       404.073129
# min        47.840000
# 25%       349.835000
# 50%       581.275000
# 75%       911.947500
# max      2047.210000
# Name: Economic_Impact_Million_USD, dtype: float64

# %%
q95 = df['Economic_Impact_Million_USD'].quantile(0.95)
print(f'Q95 : {q95}')
# Out:
# Q95 : 1462.1354999999996

# %% [markdown]
# # Q2) Unique Regions for Canada

# %%
canada_regions = df[df['Country'] == 'Canada']['Region'].nunique()
print("Number of Unique Regions in Canada:")
print(canada_regions)
# Out:
# Number of Unique Regions in Canada:
# 4

# %%
df[['Country', 'Region']][df['Country']=='Canada'].value_counts()
# Out:
# Country  Region
# Canada   Ontario             268
#          Prairies            243
#          British Columbia    242
#          Quebec              230
# Name: count, dtype: int64

# %% [markdown]
# # Q3) CO2 Emissions in 2023

# %%
df.head()
# Out:
#         Date Country         Region  Crop_Type  Average_Temperature_C  \
# 0 2001-01-15   India    West Bengal       Corn                   1.55
# 1 2024-01-15   China          North       Corn                   3.23
# 2 2001-01-15  France  Ile-de-France      Wheat                  21.11
# 3 2001-01-15  Canada       Prairies     Coffee                  27.85
# 4 1998-01-15   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_Perc  Pesticide_Use_KG_per_HA  \
# 0                       8                   14.54                    10.08
# 1                       8                   11.05                    33.06
# 2                       5                   84.42                    27.41
# 3                       5                   94.06                    14.38
# 4                       9                   95.75                    44.35
#
#    Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 0                     14.78              83.25      Water Management
# 1                     23.25              54.02         Crop Rotation
# 2                     65.53              67.78      Water Management
# 3                     87.58              91.39         No Adaptation
# 4                     88.08              49.61         Crop Rotation
#
#    Economic_Impact_Million_USD
# 0                       808.13
# 1                       616.22
# 2                       796.96
# 3                       790.32
# 4                       401.72

# %%
df['CO2_Emissions_MT'].describe()
# Out:
# count    9958.000000
# mean       15.262319
# std         8.591088
# min         0.500000
# 25%         7.772500
# 50%        15.230000
# 75%        22.840000
# max        30.000000
# Name: CO2_Emissions_MT, dtype: float64

# %%
df_2023=df[df['Date'].dt.year==2023]

# %%
co2_emissions_by_country = df_2023.groupby('Country')['CO2_Emissions_MT'].sum().reset_index().sort_values(by='CO2_Emissions_MT', ascending=False)
co2_emissions_by_country
# Out:
#      Country  CO2_Emissions_MT
# 6      India            542.09
# 7    Nigeria            499.99
# 5     France            491.78
# 3     Canada            480.91
# 2     Brazil            438.08
# 4      China            430.50
# 0  Argentina            407.33
# 8     Russia            406.57
# 1  Australia            404.74
# 9        USA            359.43

# %%
most_co2_emissions = co2_emissions_by_country.loc[co2_emissions_by_country['CO2_Emissions_MT'].idxmax()]
least_co2_emissions = co2_emissions_by_country.loc[co2_emissions_by_country['CO2_Emissions_MT'].idxmin()]

# %%
print(f"The country with the most CO2 emissions in 2023 is {most_co2_emissions['Country']} with {most_co2_emissions['CO2_Emissions_MT']} metric tons of CO2.")
# Out:
# The country with the most CO2 emissions in 2023 is India with 542.09 metric tons of CO2.

# %%
print(f"The country with the least CO2 emissions in 2023 is {least_co2_emissions['Country']} with {least_co2_emissions['CO2_Emissions_MT']} metric tons of CO2.")
# Out:
# The country with the least CO2 emissions in 2023 is USA with 359.43 metric tons of CO2.

# %%
plt.figure(figsize=(12, 6),dpi=200)
sns.set_style("whitegrid")
sns.barplot(x='Country', y='CO2_Emissions_MT', data=co2_emissions_by_country, palette='viridis')
plt.title('CO2 Emissions by Country')
plt.xlabel('Country')
plt.ylabel('CO2 Emissions (metric tons)')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10256\2924109969.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='CO2_Emissions_MT', data=co2_emissions_by_country, palette='viridis')

# %% [markdown]
# # Q4) Coolest Region in the USA

# %%
df['Average_Temperature_C'].describe()
# Out:
# count    9958.000000
# mean       15.241641
# std        11.489669
# min        -4.990000
# 25%         5.390000
# 50%        15.170000
# 75%        25.360000
# max        35.000000
# Name: Average_Temperature_C, dtype: float64

# %%
df_usa = df[df['Country']=='USA']

# %%
df_usa['Average_Temperature_C'].describe()
# Out:
# count    1027.000000
# mean       15.683574
# std        11.626098
# min        -4.980000
# 25%         5.725000
# 50%        15.620000
# 75%        25.990000
# max        34.980000
# Name: Average_Temperature_C, dtype: float64

# %%
df_usa['Region'].unique()
# Out:
# array(['Midwest', 'Northeast', 'South', 'West'], dtype=object)

# %%
df_usa['Region'].value_counts()
# Out:
# Region
# South        262
# Northeast    259
# West         255
# Midwest      251
# Name: count, dtype: int64

# %%
df_usa[df_usa['Region']=='South'].head(5)
# Out:
#           Date Country Region   Crop_Type  Average_Temperature_C  \
# 25  1996-01-15     USA  South    Soybeans                  27.73
# 45  2024-01-15     USA  South       Wheat                  12.18
# 118 1997-01-15     USA  South      Coffee                  34.07
# 128 2000-01-15     USA  South  Vegetables                  23.61
# 198 2004-01-15     USA  South  Vegetables                  -4.37
#
#      Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 25                  1673.81             26.56                 3.285
# 45                  1647.58             19.10                 1.872
# 118                 1965.45             20.34                 2.853
# 128                 1287.10             17.00                 1.476
# 198                 2292.03             29.68                 2.583
#
#      Extreme_Weather_Events  Irrigation_Access_Perc  Pesticide_Use_KG_per_HA  \
# 25                        1                   88.61                    29.11
# 45                        8                   36.61                    43.15
# 118                       9                   49.77                    29.93
# 128                       7                   64.45                    49.46
# 198                       2                   13.27                    22.33
#
#      Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 25                      27.82              96.40            No Adaptation
# 45                      22.46              52.18         Water Management
# 118                      1.12              49.98  Drought-resistant Crops
# 128                     29.43              52.68            Crop Rotation
# 198                     52.30              97.11            No Adaptation
#
#      Economic_Impact_Million_USD
# 25                       1492.19
# 45                        925.79
# 118                       642.36
# 128                       329.19
# 198                       878.12

# %%
df_usa_region_temp = df_usa.groupby('Region')['Average_Temperature_C'].mean()
df_usa_region_temp
# Out:
# Region
# Midwest      16.606335
# Northeast    15.517452
# South        15.378702
# West         15.257255
# Name: Average_Temperature_C, dtype: float64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(20, 10), dpi=200)

sns.barplot(x=df_usa_region_temp.values, y=df_usa_region_temp.index, edgecolor='black', linewidth=1.2)

plt.xlabel('Average Temperature (Celsius)')
plt.ylabel('Region')
plt.title('Average Temperature in USA by Region', fontdict={'fontsize': 18,'fontweight': 'bold'})
plt.tight_layout()
plt.show()

# %%
a= df_usa_region_temp.idxmin()

# %%
print(f'The Region with the lowest Average Temperature(Coolest_region) in USA is {a}')
# Out:
# The Region with the lowest Average Temperature(Coolest_region) in USA is West

# %% [markdown]
# # Q5) Crop Type with Highest Economic Impact in the Midwest

# %%
df_usa.head(10)
# Out:
#           Date Country     Region   Crop_Type  Average_Temperature_C  \
# 5   2019-01-15     USA    Midwest      Coffee                  17.19
# 13  2003-01-15     USA  Northeast      Barley                  14.70
# 25  1996-01-15     USA      South    Soybeans                  27.73
# 45  2024-01-15     USA      South       Wheat                  12.18
# 60  2023-01-15     USA  Northeast      Cotton                  30.62
# 63  2021-01-15     USA  Northeast      Fruits                  23.30
# 66  2011-01-15     USA       West        Corn                  15.76
# 70  2019-01-15     USA  Northeast  Vegetables                  24.62
# 91  1993-01-15     USA       West        Rice                  18.05
# 118 1997-01-15     USA      South      Coffee                  34.07
#
#      Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 5                    975.13             10.73                 2.180
# 13                  2272.28             11.45                 2.500
# 25                  1673.81             26.56                 3.285
# 45                  1647.58             19.10                 1.872
# 60                  1630.22             29.28                 3.249
# 63                  1740.68             25.99                 0.747
# 66                  2317.59             21.33                 3.807
# 70                  1342.63             27.04                 2.628
# 91                   391.16             18.64                 3.960
# 118                 1965.45             20.34                 2.853
#
#      Extreme_Weather_Events  Irrigation_Access_Perc  Pesticide_Use_KG_per_HA  \
# 5                         5                   52.45                    26.06
# 13                        9                   57.37                    19.48
# 25                        1                   88.61                    29.11
# 45                        8                   36.61                    43.15
# 60                        9                   70.31                     5.80
# 63                       10                   44.50                     4.74
# 66                        0                   94.85                    47.02
# 70                        0                   15.98                     9.00
# 91                        5                   91.05                     3.76
# 118                       9                   49.77                    29.93
#
#      Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 5                       71.56              97.32         Water Management
# 13                      46.13              77.32  Drought-resistant Crops
# 25                      27.82              96.40            No Adaptation
# 45                      22.46              52.18         Water Management
# 60                      49.85              31.92            Crop Rotation
# 63                      20.44              60.39            No Adaptation
# 66                      35.76              48.60  Drought-resistant Crops
# 70                      49.51              81.09            No Adaptation
# 91                      99.89              37.87            Crop Rotation
# 118                      1.12              49.98  Drought-resistant Crops
#
#      Economic_Impact_Million_USD
# 5                         353.16
# 13                       1126.27
# 25                       1492.19
# 45                        925.79
# 60                        509.77
# 63                        372.06
# 66                       1627.44
# 70                        548.31
# 91                       1009.71
# 118                       642.36

# %%
df_usa_midwest = df_usa[df_usa['Region']=='Midwest']

# %%
df_usa_midwest.head()
# Out:
#           Date Country   Region   Crop_Type  Average_Temperature_C  \
# 5   2019-01-15     USA  Midwest      Coffee                  17.19
# 124 2012-01-15     USA  Midwest  Vegetables                  -3.77
# 132 1994-01-15     USA  Midwest  Vegetables                  13.55
# 165 2013-01-15     USA  Midwest        Corn                   5.74
# 178 2005-01-15     USA  Midwest      Fruits                  17.33
#
#      Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 5                    975.13             10.73                 2.180
# 124                  698.50             27.68                 1.206
# 132                 2895.80              1.50                 3.550
# 165                 2114.15             13.19                 2.940
# 178                 1339.45              9.85                 3.450
#
#      Extreme_Weather_Events  Irrigation_Access_Perc  Pesticide_Use_KG_per_HA  \
# 5                         5                   52.45                    26.06
# 124                       2                   69.03                    14.97
# 132                       6                   94.31                    48.76
# 165                       9                   31.08                    13.41
# 178                       0                   97.49                    44.92
#
#      Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 5                       71.56              97.32         Water Management
# 124                      9.47              80.00            No Adaptation
# 132                     23.63              74.06         Water Management
# 165                     31.29              86.23  Drought-resistant Crops
# 178                     81.19              36.40            No Adaptation
#
#      Economic_Impact_Million_USD
# 5                         353.16
# 124                       268.11
# 132                      1316.20
# 165                       413.76
# 178                      1185.31

# %%
df_usa_midwest.Crop_Type.unique()
# Out:
# array(['Coffee', 'Vegetables', 'Corn', 'Fruits', 'Wheat', 'Soybeans',
#        'Barley', 'Sugarcane', 'Rice', 'Cotton'], dtype=object)

# %%
df_usa_midwest.Crop_Type.value_counts()
# Out:
# Crop_Type
# Coffee        35
# Wheat         33
# Vegetables    31
# Barley        28
# Rice          23
# Corn          21
# Fruits        21
# Cotton        21
# Soybeans      20
# Sugarcane     18
# Name: count, dtype: int64

# %%
df_usa_midwest_highest_impact = df_usa_midwest.groupby('Crop_Type')['Economic_Impact_Million_USD'].sum().sort_values(ascending=False)
df_usa_midwest_highest_impact
# Out:
# Crop_Type
# Coffee        21970.56
# Wheat         21299.82
# Vegetables    19198.26
# Barley        16768.63
# Soybeans      14577.64
# Rice          13830.13
# Cotton        13666.43
# Corn          13540.37
# Fruits        12842.23
# Sugarcane     11476.57
# Name: Economic_Impact_Million_USD, dtype: float64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6), dpi=200)
plt.bar(df_usa_midwest_highest_impact.index, df_usa_midwest_highest_impact.values, color='darkblue')
plt.xlabel('Crop Type')
plt.ylabel('Economic Impact (Million USD)')
plt.title('Economic Impact by Crop Type in Midwest in USA', fontdict={'fontsize': 18,'fontweight': 'bold'})
plt.xticks(rotation=45)
plt.show()

# %%
j= df_usa_midwest.groupby('Crop_Type')['Economic_Impact_Million_USD'].sum().idxmax()

# %%
print(f'The Crop Type with the highest Economic Impact in Midwest in USA is {j}')
# Out:
# The Crop Type with the highest Economic Impact in Midwest in USA is Coffee

# %% [markdown]
# # Q6) Yearly Average Precipitation in Australia

# %%
df_aus = df[df['Country']=='Australia']

# %%
df_aus.head()
# Out:
#          Date    Country             Region  Crop_Type  Average_Temperature_C  \
# 7  2021-01-15  Australia    New South Wales       Rice                  25.63
# 20 2000-01-15  Australia    New South Wales       Rice                  30.08
# 23 2010-01-15  Australia           Victoria     Coffee                  20.85
# 29 1997-01-15  Australia           Victoria      Wheat                  31.67
# 40 2020-01-15  Australia  Western Australia  Sugarcane                  17.77
#
#     Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 7                   786.17              7.77                 3.270
# 20                 1641.99             15.83                 3.096
# 23                 2294.81              8.66                 2.820
# 29                 2364.58             13.16                 3.330
# 40                 1743.11             13.69                 1.690
#
#     Extreme_Weather_Events  Irrigation_Access_Perc  Pesticide_Use_KG_per_HA  \
# 7                        4                   66.53                    13.44
# 20                       2                   94.75                    13.70
# 23                       3                   39.88                    29.31
# 29                       4                   72.38                    48.77
# 40                       2                   23.95                    39.15
#
#     Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 7                      40.50              63.16  Drought-resistant Crops
# 20                     42.84              73.56          Organic Farming
# 23                     79.91              59.92  Drought-resistant Crops
# 29                     12.25              94.46  Drought-resistant Crops
# 40                     67.61              42.34         Water Management
#
#     Economic_Impact_Million_USD
# 7                       1367.97
# 20                       345.85
# 23                      1222.94
# 29                      1244.49
# 40                       440.49

# %%
df_aus[['Date','Total_Precipitation_mm']].sort_values(by='Date')
# Out:
#            Date  Total_Precipitation_mm
# 9237 1990-01-15                  232.69
# 472  1990-01-15                  792.95
# 9792 1990-01-15                 1626.77
# 2999 1990-01-15                  229.38
# 519  1990-01-15                 1794.74
# ...         ...                     ...
# 7063 2024-01-15                  604.40
# 7044 2024-01-15                  870.49
# 4558 2024-01-15                 1361.30
# 8322 2024-01-15                 1413.98
# 8868 2024-01-15                  362.02
#
# [1029 rows x 2 columns]

# %%
df_aus_yearly_avg_prec= df_aus.groupby(df_aus['Date'].dt.year)['Total_Precipitation_mm'].mean()
df_aus_yearly_avg_prec
# Out:
# Date
# 1990    1507.071852
# 1991    1611.487200
# 1992    1597.907742
# 1993    1721.504848
# 1994    1736.621471
# 1995    1667.870385
# 1996    1559.578824
# 1997    1476.702500
# 1998    1292.173077
# 1999    1512.938485
# 2000    1481.743333
# 2001    1572.743514
# 2002    1521.596190
# 2003    1370.349231
# 2004    1774.911515
# 2005    1472.015185
# 2006    1875.185926
# 2007    1794.957931
# 2008    1836.530286
# 2009    1557.533478
# 2010    1593.906774
# 2011    1460.837273
# 2012    1704.759474
# 2013    1590.485769
# 2014    1595.904634
# 2015    1674.129615
# 2016    1574.668462
# 2017    1449.117222
# 2018    1766.157727
# 2019    1698.361852
# 2020    1599.074444
# 2021    1512.417273
# 2022    1500.565278
# 2023    1462.101724
# 2024    1539.947222
# Name: Total_Precipitation_mm, dtype: float64

# %%
plt.figure(figsize=(16, 8),dpi=200)
sns.lineplot(x=df_aus_yearly_avg_prec.index, y=df_aus_yearly_avg_prec.values, color='brown')
plt.xticks(rotation=45)
plt.title('Yearly Average Precipitation in Australia',fontdict={'fontsize':15})
plt.xlabel('Year')
plt.ylabel('Average Precipitation (mm)')
plt.legend(['Average Precipitation'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Q7) Associations Among Variables

# %%
numeric_cols
# Out:
# Index(['Average_Temperature_C', 'Total_Precipitation_mm', 'CO2_Emissions_MT',
#        'Crop_Yield_MT_per_HA', 'Extreme_Weather_Events',
#        'Irrigation_Access_Perc', 'Pesticide_Use_KG_per_HA',
#        'Fertilizer_Use_KG_per_HA', 'Soil_Health_Index',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="YlGnBu", fmt='.2f', annot_kws={"size": 10})
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
new_numeric_cols = numeric_cols.drop(['Crop_Yield_MT_per_HA','Irrigation_Access_Perc'])

# %%
new_numeric_cols
# Out:
# Index(['Average_Temperature_C', 'Total_Precipitation_mm', 'CO2_Emissions_MT',
#        'Extreme_Weather_Events', 'Pesticide_Use_KG_per_HA',
#        'Fertilizer_Use_KG_per_HA', 'Soil_Health_Index',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
corr_mat = df[new_numeric_cols].corr()

# %%
corr_mat
# Out:
#                              Average_Temperature_C  Total_Precipitation_mm  \
# Average_Temperature_C                     1.000000                0.007400
# Total_Precipitation_mm                    0.007400                1.000000
# CO2_Emissions_MT                         -0.003029               -0.008946
# Extreme_Weather_Events                   -0.016961                0.004721
# Pesticide_Use_KG_per_HA                   0.005723                0.011179
# Fertilizer_Use_KG_per_HA                 -0.014802               -0.025516
# Soil_Health_Index                        -0.010976               -0.020286
# Economic_Impact_Million_USD               0.201446                0.019197
#
#                              CO2_Emissions_MT  Extreme_Weather_Events  \
# Average_Temperature_C               -0.003029               -0.016961
# Total_Precipitation_mm              -0.008946                0.004721
# CO2_Emissions_MT                     1.000000                0.000897
# Extreme_Weather_Events               0.000897                1.000000
# Pesticide_Use_KG_per_HA              0.014655                0.010731
# Fertilizer_Use_KG_per_HA            -0.019824                0.014614
# Soil_Health_Index                    0.005052                0.016687
# Economic_Impact_Million_USD         -0.051904               -0.003968
#
#                              Pesticide_Use_KG_per_HA  \
# Average_Temperature_C                       0.005723
# Total_Precipitation_mm                      0.011179
# CO2_Emissions_MT                            0.014655
# Extreme_Weather_Events                      0.010731
# Pesticide_Use_KG_per_HA                     1.000000
# Fertilizer_Use_KG_per_HA                   -0.015534
# Soil_Health_Index                           0.013561
# Economic_Impact_Million_USD                -0.007036
#
#                              Fertilizer_Use_KG_per_HA  Soil_Health_Index  \
# Average_Temperature_C                       -0.014802          -0.010976
# Total_Precipitation_mm                      -0.025516          -0.020286
# CO2_Emissions_MT                            -0.019824           0.005052
# Extreme_Weather_Events                       0.014614           0.016687
# Pesticide_Use_KG_per_HA                     -0.015534           0.013561
# Fertilizer_Use_KG_per_HA                     1.000000           0.000199
# Soil_Health_Index                            0.000199           1.000000
# Economic_Impact_Million_USD                  0.007780          -0.001151
#
#                              Economic_Impact_Million_USD
# Average_Temperature_C                           0.201446
# Total_Precipitation_mm                          0.019197
# CO2_Emissions_MT                               -0.051904
# Extreme_Weather_Events                         -0.003968
# Pesticide_Use_KG_per_HA                        -0.007036
# Fertilizer_Use_KG_per_HA                        0.007780
# Soil_Health_Index                              -0.001151
# Economic_Impact_Million_USD                     1.000000

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_mat, annot=True, cmap='coolwarm', fmt='.2f', annot_kws={"size": 10})
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# Among all the associations analyzed, one stands out as more significant than the others.
#
# *  **Association**: Average Temperature and Economic Impact
#
# *  **Correlation Coefficient**: 0.2014
#
# *  **Interpretation**: This shows a weak positive correlation.
#
# *  **Conclusion**: With the rise in average temperatures, the economical impact also tends to increase. This relationship is impressive when compared with the rest of the associations that are present within the dataset.
# *   **Further Analysis Needed**: More features need to be sought in order to have a better understanding of this relationship.

# %%
rows, columns = df.shape

# %%
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 9958
# Number of columns: 15

# %%
s
